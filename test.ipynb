# %%
import xml.etree.ElementTree as ET
import requests

# URL del .mpd
mpd_url = "https://ott-video-fer-cf.formula1.com/v2/pa_-YzQ1d2VDeH5Pa1VSOTVQTmgtQ1V0NHAyYWw2UEVf/a723ea61e7b8eb21fd7497e842f4db92/out/v1/0a09df3a3ceb4a8d8dd3a2ec152fd73b/2bf77a4c2fd34c81a3f138428d11a04b/cd3f53828a8a4061adaca530fa8bf86a/index.mpd"

# Descargar el .mpd
resp = requests.get(mpd_url)
resp.raise_for_status()
mpd_content = resp.text

# Parsear el XML
root = ET.fromstring(mpd_content)

# Namespaces (algunos MPD usan estos)
ns = {'mpd': 'urn:mpeg:dash:schema:mpd:2011'}

# Verificar DRM
drm_tags = root.findall('.//mpd:ContentProtection', ns)
if drm_tags:
    print("⚠️ Este MPD está protegido con DRM.")
else:
    print("✅ No parece tener DRM.")

# Listar pistas de audio
for adaptation_set in root.findall('.//mpd:AdaptationSet', ns):
    if adaptation_set.get('mimeType', '').startswith('audio'):
        lang = adaptation_set.get('lang', 'desconocido')
        print(f"🎧 Pista de audio encontrada - Idioma: {lang}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       7 # Descargar el .mpd
#       8 resp = requests.get(mpd_url)
# ----> 9 resp.raise_for_status()
#      10 mpd_content = resp.text
#      12 # Parsear el XML
#
# File d:\Github\video_diarization\venv\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
ffmpeg -i "https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/e4dc938766ab413c9af41d52161fae13/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8" -map 0:v:0 -map 0:a:m:language:spa -c:v copy -c:a copy "nombre_de_la_carrera.mp4"

# %%
ffprobe "https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/e4dc938766ab413c9af41d52161fae13/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8"

# %%
ffmpeg -i "https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/e4dc938766ab413c9af41d52161fae13/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8" -map p:3 -map 0:a:m:language:spa -c copy "nombre_de_la_carrera_HD.mp4"

# %%
ffmpeg -i "https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/7fe6e5be6999421abbd02695d260da15/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8" -map 0:v:3 -map 0:a:m:language:spa -c:v copy -c:a copy "GP Miami 2025 Qualy.mp4"

# %%
https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/a86cda766a3247869355c0b304e77cea/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8

# %%
import subprocess

cmd = [
    "ffmpeg",
    "-i", url,
    "-map", "0:v:3",
    "-map", "0:a:m:language:eng",
    "-c:v", "copy",
    "-c:a", "copy",
    name + "idioma.mp4"
]

subprocess.run(cmd)
# Out:
# CompletedProcess(args=['ffmpeg', '-i', 'https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/a86cda766a3247869355c0b304e77cea/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8', '-map', '0:v:3', '-map', '0:a:m:language:eng', '-c:v', 'copy', '-c:a', 'copy', 'GP Miami 2025 FP1 eng.mp4'], returncode=0)

# %%
import subprocess

# Asumo que las variables 'url' y 'name' están definidas en una celda anterior
# url = "https://..."
# name = "GP Miami 2025 FP1"
#"spa", "eng", "fra", "por",
languages = ["spa", "eng", "fra", "por", "deu", "nld"]
base_name = name.replace(".mp4", "") # Quita la extensión si la tiene


for lang in languages:
    output_filename = f"{base_name}_{lang}.mp4"
    print(f"--- Procesando idioma: {lang} -> {output_filename} ---")

    cmd = [
        "ffmpeg",
        "-i", url,
        "-map", "0:v:3",                      # Mapea la pista de video (ajusta si es necesario)
        f"-map", f"0:a:m:language:{lang}",    # Mapea la pista de audio para el idioma actual
        "-c:v", "copy",
        "-c:a", "copy",
        output_filename
    ]

    # Ejecuta el comando y captura la salida para verificar errores
    result = subprocess.run(cmd, capture_output=True, text=True)

    if result.returncode == 0:
        print(f"✅ Descarga para '{lang}' completada exitosamente.")
    else:
        print(f"❌ Error al descargar para '{lang}'. El stream de audio puede no estar disponible.")
        # Imprime el error de ffmpeg para más detalles
        print(result.stderr)

print("\nProceso finalizado para todos los idiomas.")
# Out:
# --- Procesando idioma: spa -> D:\Transmiciones F1\GP Arabia 2025 Carrera_spa.mp4 ---
# ✅ Descarga para 'spa' completada exitosamente.
# --- Procesando idioma: eng -> D:\Transmiciones F1\GP Arabia 2025 Carrera_eng.mp4 ---
# ✅ Descarga para 'eng' completada exitosamente.
# --- Procesando idioma: fra -> D:\Transmiciones F1\GP Arabia 2025 Carrera_fra.mp4 ---
# ✅ Descarga para 'fra' completada exitosamente.
# --- Procesando idioma: por -> D:\Transmiciones F1\GP Arabia 2025 Carrera_por.mp4 ---
# ✅ Descarga para 'por' completada exitosamente.
# --- Procesando idioma: deu -> D:\Transmiciones F1\GP Arabia 2025 Carrera_deu.mp4 ---
# ✅ Descarga para 'deu' completada exitosamente.
# --- Procesando idioma: nld -> D:\Transmiciones F1\GP Arabia 2025 Carrera_nld.mp4 ---
# ✅ Descarga para 'nld' completada exitosamente.
#
# Proceso finalizado para todos los idiomas.

# %%
import subprocess
import os

# Asumo que las variables 'url' y 'name' están definidas en una celda anterior
# url = "https://..."
# name = r"D:\Transmiciones F1\GP Arabia 2025 Carrera"
name = r"D:\Transmiciones F1"
languages = ["spa", "eng", "fra", "por", "deu", "nld"]
video_track_selector = "0:v:3" # Pista de video a usar
primary_lang = languages[0]

# --- 1. Descargar el video con la primera pista de audio (español) ---
for i in races_dic:
    for x in races_dic[i]:

        try:
            os.makedirs(f"{base_name}/{i}/{x}")
        except:
            print(f"{base_name}/{i}/{x}" + 'Carpeta ya existe')
        
        video_output_filename = f"{base_name}/{i}/{x}/{i}_{x}_video_{primary_lang}.mp4"

        print(f"--- Descargando video principal con audio en '{primary_lang}' ---")
        print(f"Archivo de salida: {video_output_filename}")

        video_cmd = [
            "ffmpeg",
            "-i", races_dic[i],
            "-map", video_track_selector,
            f"-map", f"0:a:m:language:{primary_lang}",
            "-c:v", "copy",
            "-c:a", "copy",
            video_output_filename
        ]

        # Ejecuta el comando para el video
        video_result = subprocess.run(video_cmd, capture_output=True, text=True)

        if video_result.returncode == 0:
            print(f"✅ Video descargado exitosamente.")
        else:
            print(f"❌ Error al descargar el video principal.")
            print(video_result.stderr)


        # --- 2. Descargar todas las pistas de audio como archivos separados ---
        print("\n--- Iniciando descarga de pistas de audio adicionales ---")

        for lang in languages:
            audio_output_filename =f"{base_name}/{i}/{x}/{i}_{x}_audio_{lang}.m4a"
            print(f"--- Procesando audio: {lang} -> {audio_output_filename} ---")

            audio_cmd = [
                "ffmpeg",
                "-i", races_dic[i],
                f"-map", f"0:a:m:language:{lang}",    # Mapea solo la pista de audio para el idioma actual
                "-c:a", "copy",                      # Copia el stream de audio sin recodificar
                audio_output_filename
            ]

            # Ejecuta el comando y captura la salida para verificar errores
            result = subprocess.run(audio_cmd, capture_output=True, text=True)

            if result.returncode == 0:
                print(f"✅ Audio para '{lang}' descargado exitosamente.")
            else:
                print(f"❌ Error al descargar audio para '{lang}'. El stream puede no estar disponible.")
                print(result.stderr)

print("\nProceso finalizado.")
# Out:
# --- Descargando video principal con audio en 'spa' ---
# Archivo de salida: D:\Transmiciones F1\GP Miami 2025 Sprint_video_spa.mp4
# ✅ Video descargado exitosamente.
#
# --- Iniciando descarga de pistas de audio adicionales ---
# --- Procesando audio: spa -> D:\Transmiciones F1\GP Miami 2025 Sprint_audio_spa.m4a ---
# ✅ Audio para 'spa' descargado exitosamente.
# --- Procesando audio: eng -> D:\Transmiciones F1\GP Miami 2025 Sprint_audio_eng.m4a ---
# ✅ Audio para 'eng' descargado exitosamente.
# --- Procesando audio: fra -> D:\Transmiciones F1\GP Miami 2025 Sprint_audio_fra.m4a ---
# ✅ Audio para 'fra' descargado exitosamente.
# --- Procesando audio: por -> D:\Transmiciones F1\GP Miami 2025 Sprint_audio_por.m4a ---
# ✅ Audio para 'por' descargado exitosamente.
# --- Procesando audio: deu -> D:\Transmiciones F1\GP Miami 2025 Sprint_audio_deu.m4a ---
# ✅ Audio para 'deu' descargado exitosamente.
# --- Procesando audio: nld -> D:\Transmiciones F1\GP Miami 2025 Sprint_audio_nld.m4a ---
# ...

# %%
f1tv = {
    'Australia':{
                'Carrera':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/3cf0b37c925b4c1ba0ebace224bd2c7b/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'Qualy':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/851bbc1287164734a960ab6b277d39f7/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP3':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/64d22e40f9024d9e885f57be01e8ba6d/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP2':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/e3e77e742ac547568069259132539027/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP1':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/ef180215c91a421496c7e502a2c28859/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8"
                },
    'China':{
                'Carrera':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/54254f948ac04000aba8914d4df3f8f5/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'Qualy':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/999fca7f4ff24e3792effd9b63450c4e/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'Carrera Sprint':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/932ae245e0254e91b3d07c2163372d34/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'Qualy Sprint':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/ae5b562316174b82858a0220b7928ba8/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP1':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/e8cf4c4da49f455c9df86b167ecd86aa/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8"
                },
    'Japon':{
                'Carrera':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/9a6f114c91e34a5cb87d074a4b7b1ced/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'Qualy':"https://ott-video-fer-cf.formula1.com/v2/pa__/f405469823c4f566b25c9a57e8de17c4/out/v1/6f9f4eff685e4084bab60abfdca00b58/946e14a2ef204e3896ef47ef5f44e9db/42f2b4793ed04c6d9ab17f1a4ca468ae/index.m3u8",
                'FP3':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/17cc9465a36d4246bed7eccbd3088037/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP2':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/5c70a4fe3f404a3cb77d4490e8a26598/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP1':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/b1d2e863c1e04e94a5de6f68316352d0/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8"
                },
    'Bahrain':{
                'Carrera':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/6d70e27703e64adbbfa40cb840a41da0/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'Qualy':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/11753b96d1254763b050f3cc4dee6191/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP3':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/76a9279b40a24519a8ca4f33f154c9e1/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP2':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/a383529162b8442ca410b7e4a3f46a11/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP1':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/517234dc79324660aa98f62fda4e6d32/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8"
                },
    'Arabia':{
                'Carrera':"https://ott-video-fer-cf.formula1.com/v2/pa_-MWQ1TGYyM3RFZHVBdzdaelVBSW1UbnRlSV8_/a723ea61e7b8eb21fd7497e842f4db92/out/v1/042dc848a9ee4614b120571fc0aab2ee/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'Qualy':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/6891326c3dc344709326e2e9a838c85a/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'FP3':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/d08c3927d3384a7f82fe2e7fa8ae2abe/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
                'F
da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'bahrain':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/d08aa2fcc5154680b3cb4b38d27083b5/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'arabia':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/042dc848a9ee4614b120571fc0aab2ee/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    
    
    'miami sprint':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/2435775933c846569d5b0ce311c67493/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'miami':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/e4dc938766ab413c9af41d52161fae13/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    
    'imola':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/1d154c93f8674b70b69868a651b9bee0/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    
    'monaco':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/526e1ff2e7e94f898b68f48d9f6357cf/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'espana':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/43e6a35ae89b437988a3d505cfa78b1d/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'canada':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/70b4b9316df94588b40262cae8b7252d/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'austria':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/cbafcf2c834a430f9a983dcc876b370d/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'silverstone':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/cc11449e97ec41fca7a8bcb33e408c9c/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'belgica':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/c3ffff1acca142fd9474704e289a06fc/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'belgica sprint':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/c76381d6d4ed46e5b30dd2269199ab5b/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8",
    'hungria':"https://ott-video-fer-cf.formula1.com/v2/pa__/a723ea61e7b8eb21fd7497e842f4db92/out/v1/a1637e2430e64088b30f482e95b59ba1/da96b587f3f94837be07cec7df5aabaa/970552fa460041eeb829abf7b4bf23f8/index.m3u8"
 }

# %%
races_dic1 = {'Imola':races_dic['Imola']}

# %%
import subprocess
import os

base_download_path = r"D:\Transmiciones F1"
languages = ["spa", "eng", "fra", "por", "deu", "nld"]
video_track_selector = "0:v:3"

# Iterar sobre cada Gran Premio en el diccionario
for gp_name, sessions in races_dic1.items():
    # Iterar sobre cada sesión (Carrera, Qualy, etc.)
    for session_name, session_url in sessions.items():
        
        # 1. VERIFICACIÓN: Saltar si la URL está vacía
        if not session_url:
            print(f"--- Saltando {gp_name} - {session_name} (URL no disponible) ---\n")
            continue

        print(f"--- Procesando: {gp_name} - {session_name} ---")

        # 2. PREPARACIÓN DE RUTAS Y ARCHIVOS
        # Crear la ruta de la carpeta de forma segura
        output_dir = os.path.join(base_download_path, gp_name, session_name)
        os.makedirs(output_dir, exist_ok=True)

        # Nombre base para los archivos de esta sesión
        file_base_name = f"{gp_name}_{session_name}"
        
        # 3. CONSTRUIR UN ÚNICO COMANDO FFMPEG
        cmd = ["ffmpeg", "-i", session_url]

        # Mapear la pista de video a un archivo .mp4
        video_output_path = os.path.join(output_dir, f"{file_base_name}_video.mp4")
        cmd.extend(["-map", video_track_selector, "-c:v", "copy", video_output_path])

        # Mapear CADA pista de audio a su propio archivo .m4a
        for lang in languages:
            audio_output_path = os.path.join(output_dir, f"{file_base_name}_audio_{lang}.m4a")
            cmd.extend([f"-map", f"0:a:m:language:{lang}", "-c:a", "copy", audio_output_path])

        # 4. EJECUTAR EL COMANDO
        print(f"Ejecutando comando para descargar video y todos los audios...")
        print("Comando:", " ".join(cmd)) # Descomenta para depurar y ver el comando completo
        
        result = subprocess.run(cmd, capture_output=True, text=True, encoding='utf-8')

        if result.returncode == 0:
            print(f"✅ Descarga completada exitosamente para {gp_name} - {session_name}\n")
        else:
            print(f"❌ Error al procesar {gp_name} - {session_name}.")
            print("FFmpeg stderr (puede indicar qué pistas de audio faltan):")
            print(result.stderr)
            print("\n")

print("--- Proceso finalizado para todas las carreras. ---")
# Out:
# --- Procesando: Miami - Carrera ---
# Ejecutando comando para descargar video y todos los audios...
# ...
